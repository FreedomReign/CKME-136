# %%
# Prolog - Auto Generated #
import os, matplotlib, matplotlib.pyplot as plt, uuid, pandas as pd, numpy as np
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %matplotlib inline

# %%
#Youtube : Learn Pandas
#https://www.youtube.com/watch?v=v66K_y3-ezY

import pandas_datareader as dr
import datetime
import pandas_datareader.data as web

# %%
start=datetime.datetime(2012,1,1)
end=datetime.datetime(2019,4,1)

# %%
# tesla = web.DataReader('TSLA', 'google', start,end)
tesla = dr.data.get_data_yahoo('TSLA', start=start, end=end)

# %%
tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1823 entries, 2012-01-03 to 2019-04-02
# Data columns (total 6 columns):
# High         1823 non-null float64
# Low          1823 non-null float64
# Open         1823 non-null float64
# Close        1823 non-null float64
# Volume       1823 non-null int64
# Adj Close    1823 non-null float64
# dtypes: float64(5), int64(1)
# memory usage: 99.7 KB

# %%
tesla.head()
# Out:
#                  High        Low       Open      Close   Volume  Adj Close
# Date
# 2012-01-03  29.500000  27.650000  28.940001  28.080000   928100  28.080000
# 2012-01-04  28.670000  27.500000  28.209999  27.709999   630100  27.709999
# 2012-01-05  27.930000  26.850000  27.760000  27.120001  1005500  27.120001
# 2012-01-06  27.790001  26.410000  27.200001  26.910000   986300  26.910000
# 2012-01-09  27.490000  26.120001  27.000000  27.250000   897000  27.250000

# %%
tesla[['Open','Close']].plot(figsize=(16,9));

# %%
tesla['returns'] = (tesla['Close'] / tesla['Close'].shift(1))-1

# %%
tesla['returns'] = tesla['Close'].pct_change(1)

# %%
tesla['returns']
# Out:
# Date
# 2012-01-03         NaN
# 2012-01-04   -0.013177
# 2012-01-05   -0.021292
# 2012-01-06   -0.007743
# 2012-01-09    0.012635
# 2012-01-10    0.013578
# 2012-01-11    0.022085
# 2012-01-12    0.000708
# 2012-01-13   -0.193274
# 2012-01-17    0.167179
# 2012-01-18    0.007895
# 2012-01-19   -0.001865
# 2012-01-20   -0.005979
# 2012-01-23    0.006391
# 2012-01-24    0.024281
# 2012-01-25    0.020058
# 2012-01-26    0.034680
# 2012-01-27    0.013476
# 2012-01-30    0.008183
# 2012-01-31   -0.016909
# 2012-02-01    0.017544
# 2012-02-02    0.022650
# 2012-02-03    0.029752
# 2012-02-06    0.020867
# 2012-02-07   -0.006289
# 2012-02-08    0.010443
# 2012-02-09    0.020357
# 2012-02-10   -0.045427
# 2012-02-13    0.012540
# 2012-02-14    0.053350
#                 ...
# 2019-02-20   -0.010077
# 2019-02-21   -0.037447
# 2019-02-22    0.011949
# 2019-02-25    0.013776
# 2019-02-26   -0.003046
# 2019-02-27    0.056671
# 2019-02-28    0.016331
# 2019-03-01   -0.078436
# ...
